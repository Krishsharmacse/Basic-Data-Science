# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pop_data=[np.random.randint(0,200) for i in range(0,10000)]
pop_data
# Out:
# [118,
#  115,
#  14,
#  15,
#  30,
#  151,
#  39,
#  58,
#  172,
#  163,
#  13,
#  59,
#  154,
#  17,
#  95,
#  2,
#  103,
#  134,
#  122,
#  122,
#  169,
#  167,
#  117,
#  111,
#  130,
#  13,
#  89,
#  34,
#  43,
#  42,
#  123,
#  55,
#  173,
#  196,
#  181,
#  88,
#  104,
#  13,
#  196,
#  1,
#  142,
#  133,
#  60,
#  138,
#  28,
#  26,
#  71,
#  197,
#  179,
#  193,
#  18,
#  28,
#  118,
#  164,
#  100,
#  51,
#  94,
#  6,
#  148,
#  102,
#  51,
#  104,
#  193,
#  38,
#  121,
#  155,
#  161,
#  40,
#  52,
#  23,
#  197,
#  55,
#  82,
#  159,
#  169,
#  14,
#  87,
#  153,
#  70,
#  74,
#  161,
#  144,
#  196,
#  178,
#  40,
#  186,
#  55,
#  5,
#  161,
#  88,
#  135,
#  64,
#  38,
#  15,
#  173,
#  97,
#  46,
#  58,
#  152,
#  103,
#  156,
#  146,
#  72,
#  120,
#  129,
#  133,
#  16,
#  41,
#  41,
#  0,
#  87,
#  58,
#  62,
#  58,
#  128,
#  113,
#  87,
#  118,
#  69,
#  18,
#  68,
#  160,
#  48,
#  10,
#  31,
#  18,
#  122,
#  34,
#  98,
#  189,
#  155,
#  48,
#  0,
#  90,
#  52,
#  34,
#  178,
#  147,
#  171,
#  22,
#  25,
#  35,
#  29,
#  117,
#  153,
#  90,
#  192,
#  39,
#  80,
#  137,
#  191,
#  171,
#  41,
#  20,
#  35,
#  195,
#  191,
#  58,
#  81,
#  1,
#  29,
#  184,
#  38,
#  55,
#  11,
#  123,
#  185,
#  169,
#  63,
#  168,
#  54,
#  89,
#  65,
#  198,
#  45,
#  119,
#  54,
#  32,
#  155,
#  165,
#  40,
#  181,
#  107,
#  84,
#  14,
#  185,
#  42,
#  170,
#  67,
#  169,
#  156,
#  176,
#  37,
#  62,
#  0,
#  180,
#  192,
#  127,
#  74,
#  116,
#  173,
#  15,
#  160,
#  59,
#  150,
#  63,
#  119,
#  124,
#  180,
#  181,
#  75,
#  23,
#  68,
#  43,
#  194,
#  188,
#  74,
#  71,
#  99,
#  97,
#  45,
#  179,
#  18,
#  176,
#  40,
#  35,
#  180,
#  172,
#  193,
#  78,
#  67,
#  155,
#  92,
#  8,
#  147,
#  57,
#  174,
#  194,
#  128,
#  62,
#  33,
#  7,
#  3,
#  170,
#  112,
#  133,
#  7,
#  98,
#  76,
#  100,
#  85,
#  51,
#  2,
#  52,
#  129,
#  89,
#  147,
#  34,
#  11,
#  115,
#  128,
#  196,
#  174,
#  155,
#  170,
#  197,
#  5,
#  31,
#  56,
#  0,
#  164,
#  177,
#  11,
#  146,
#  150,
#  125,
#  106,
#  180,
#  197,
#  61,
#  27,
#  15,
#  0,
#  41,
#  162,
#  73,
#  16,
#  174,
#  4,
#  109,
#  26,
#  96,
#  185,
#  127,
#  129,
#  157,
#  112,
#  54,
#  51,
#  12,
#  95,
#  84,
#  119,
#  57,
#  193,
#  26,
#  89,
#  77,
#  135,
#  24,
#  92,
#  167,
#  81,
#  180,
#  64,
#  81,
#  96,
#  136,
#  186,
#  165,
#  84,
#  36,
#  62,
#  182,
#  52,
#  141,
#  189,
#  140,
#  22,
#  61,
#  117,
#  54,
#  84,
#  162,
#  127,
#  50,
#  112,
#  138,
#  118,
#  113,
#  163,
#  186,
#  53,
#  96,
#  134,
#  181,
#  13,
#  152,
#  167,
#  82,
#  44,
#  190,
#  65,
#  163,
#  78,
#  129,
#  101,
#  94,
#  61,
#  65,
#  67,
#  132,
#  104,
#  79,
#  142,
#  40,
#  112,
#  176,
#  102,
#  174,
#  144,
#  55,
#  62,
#  11,
#  146,
#  184,
#  107,
#  67,
#  22,
#  146,
#  127,
#  54,
#  56,
#  136,
#  88,
#  113,
#  158,
#  161,
#  65,
#  39,
#  82,
#  19,
#  150,
#  89,
#  194,
#  96,
#  193,
#  134,
#  109,
#  182,
#  49,
#  66,
#  3,
#  46,
#  15,
#  12,
#  81,
#  33,
#  185,
#  139,
#  130,
#  168,
#  151,
#  172,
#  21,
#  17,
#  135,
#  62,
#  192,
#  29,
#  115,
#  29,
#  149,
#  191,
#  75,
#  42,
#  112,
#  84,
#  41,
#  116,
#  149,
#  13,
#  106,
#  161,
#  70,
#  0,
#  161,
#  193,
#  26,
#  66,
#  43,
#  113,
#  188,
#  62,
#  191,
#  181,
#  88,
#  73,
#  193,
#  168,
#  20,
#  168,
#  21,
#  88,
#  142,
#  167,
#  197,
#  53,
#  192,
#  20,
#  46,
#  38,
#  176,
#  145,
#  136,
#  80,
#  8,
#  40,
#  175,
#  94,
#  134,
#  185,
#  174,
#  139,
#  45,
#  129,
#  98,
#  34,
#  179,
#  179,
#  39,
#  5,
#  77,
#  3,
#  25,
#  186,
#  66,
#  165,
#  72,
#  82,
#  107,
#  0,
#  162,
#  65,
#  10,
#  87,
#  72,
#  38,
#  38,
#  166,
#  114,
#  90,
#  84,
#  173,
#  83,
#  139,
#  65,
#  23,
#  149,
#  95,
#  137,
#  199,
#  151,
#  153,
#  197,
#  199,
#  187,
#  104,
#  38,
#  184,
#  72,
#  84,
#  175,
#  135,
#  96,
#  77,
#  7,
#  102,
#  114,
#  54,
#  11,
#  140,
#  69,
#  62,
#  34,
#  195,
#  154,
#  92,
#  75,
#  190,
#  104,
#  135,
#  125,
#  41,
#  165,
#  29,
#  8,
#  73,
#  127,
#  15,
#  170,
#  5,
#  89,
#  10,
#  135,
#  83,
#  45,
#  114,
#  18,
#  107,
#  42,
#  74,
#  5,
#  68,
#  145,
#  119,
#  184,
#  22,
#  182,
#  47,
#  176,
#  28,
#  195,
#  131,
#  133,
#  22,
#  176,
#  114,
#  123,
#  38,
#  97,
#  165,
#  4,
#  140,
#  129,
#  115,
#  73,
#  39,
#  164,
#  129,
#  156,
#  133,
#  196,
#  62,
#  168,
#  194,
#  190,
#  60,
#  43,
#  121,
#  10,
#  172,
#  13,
#  97,
#  104,
#  68,
#  0,
#  77,
#  124,
#  105,
#  165,
#  37,
#  126,
#  95,
#  101,
#  90,
#  163,
#  187,
#  177,
#  116,
#  171,
#  145,
#  118,
#  102,
#  73,
#  59,
#  84,
#  110,
#  0,
#  80,
#  168,
#  118,
#  154,
#  90,
#  6,
#  167,
#  141,
#  152,
#  193,
#  102,
#  173,
#  103,
#  116,
#  35,
#  3,
#  189,
#  143,
#  189,
#  193,
#  62,
#  88,
#  32,
#  53,
#  3,
#  153,
#  112,
#  19,
#  54,
#  78,
#  121,
#  55,
#  109,
#  163,
#  52,
#  46,
#  138,
#  126,
#  126,
#  162,
#  50,
#  122,
#  105,
#  88,
#  163,
#  135,
#  83,
#  81,
#  199,
#  172,
#  130,
#  50,
#  69,
#  190,
#  67,
#  31,
#  108,
#  143,
#  61,
#  110,
#  100,
#  118,
#  174,
#  123,
#  32,
#  33,
#  179,
#  126,
#  110,
#  73,
#  59,
#  182,
#  46,
#  159,
#  17,
#  189,
#  16,
#  33,
#  94,
#  87,
#  59,
#  39,
#  119,
#  61,
#  2,
#  134,
#  107,
#  77,
#  53,
#  57,
#  115,
#  194,
#  120,
#  21,
#  120,
#  2,
#  196,
#  109,
#  96,
#  163,
#  142,
#  144,
#  137,
#  173,
#  75,
#  50,
#  134,
#  158,
#  128,
#  153,
#  98,
#  59,
#  143,
#  185,
#  19,
#  139,
#  88,
#  9,
#  109,
#  138,
#  86,
#  70,
#  190,
#  39,
#  175,
#  84,
#  121,
#  189,
#  47,
#  148,
#  149,
#  87,
#  199,
#  40,
#  133,
#  99,
#  195,
#  75,
#  1,
#  141,
#  24,
#  4,
#  67,
#  139,
#  172,
#  30,
#  2,
#  114,
#  1,
#  138,
#  143,
#  102,
#  136,
#  55,
#  194,
#  150,
#  163,
#  22,
#  16,
#  114,
#  136,
#  97,
#  123,
#  12,
#  92,
#  179,
#  193,
#  7,
#  113,
#  9,
#  59,
#  140,
#  54,
#  144,
#  49,
#  19,
#  18,
#  171,
#  179,
#  83,
#  148,
#  14,
#  179,
#  174,
#  193,
#  147,
#  69,
#  52,
#  8,
#  165,
#  36,
#  40,
#  20,
#  72,
#  36,
#  190,
#  13,
#  40,
#  156,
#  89,
#  162,
#  191,
#  180,
#  58,
#  12,
#  138,
#  51,
#  67,
#  160,
#  139,
#  81,
#  32,
#  190,
#  151,
#  77,
#  42,
#  152,
#  70,
#  41,
#  89,
#  44,
#  13,
#  63,
#  31,
#  12,
#  184,
#  7,
#  67,
#  91,
#  162,
#  152,
#  72,
#  1,
#  158,
#  128,
#  94,
#  27,
#  43,
#  106,
#  195,
#  189,
#  128,
#  178,
#  54,
#  65,
#  137,
#  103,
#  5,
#  186,
#  157,
#  96,
#  98,
#  131,
#  175,
#  119,
#  121,
#  149,
#  146,
#  67,
#  29,
#  146,
#  140,
#  101,
#  112,
#  130,
#  50,
#  164,
#  52,
#  60,
#  97,
#  28,
#  183,
#  53,
#  113,
#  190,
#  33,
#  174,
#  9,
#  132,
#  148,
#  146,
#  106,
#  198,
#  103,
#  195,
#  115,
#  66,
#  157,
#  144,
#  31,
#  35,
#  182,
#  34,
#  194,
#  30,
#  159,
#  137,
#  185,
#  169,
#  94,
#  81,
#  34,
#  0,
#  79,
#  5,
#  53,
#  165,
#  128,
#  154,
#  199,
#  175,
#  121,
#  173,
#  106,
#  152,
#  110,
#  126,
#  148,
#  7,
#  102,
#  134,
#  70,
#  93,
#  140,
#  163,
#  120,
#  90,
#  125,
#  115,
#  174,
#  79,
#  168,
#  9,
#  184,
#  158,
#  42,
#  163,
#  57,
#  188,
#  45,
#  114,
#  30,
#  196,
#  94,
#  184,
#  43,
#  176,
#  164,
#  177,
#  61,
#  184,
#  6,
#  57,
#  191,
#  184,
#  130,
#  42,
#  21,
#  88,
#  103,
#  91,
#  182,
#  136,
#  135,
#  62,
#  125,
#  14,
#  123,
#  114,
#  187,
#  124,
#  ...]

# %%
pop_df=pd.DataFrame({"pop_data":pop_data})

# %%
pop_df
# Out:
#       pop_data
# 0          118
# 1          115
# 2           14
# 3           15
# 4           30
# ...        ...
# 9995        79
# 9996       181
# 9997        97
# 9998       135
# 9999        84
#
# [10000 rows x 1 columns]

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(pop_df)
plt.show()
# Out:
# c:\Users\Krish Sharma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Krish Sharma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Krish Sharma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sample_mean=[]
for data in range(1,100):
    sample_data=[]
    for data_teta in range(1,100):
        sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
np.mean(sample_mean)
# Out:
# 100.63901642689521
